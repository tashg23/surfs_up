# %%
# Dependencies
import numpy as np

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# I added this
import pandas as pd

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# Import the sqlalchemy extract function.
from sqlalchemy import extract

# 1. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
results_july = session.query(Measurement.tobs, Measurement.date).filter(extract('month', Measurement.date) == 7)

# %%
# 2. Convert the June temperatures to a list.
results_july.all()
# Out:
# [(75.0, '2010-07-01'),
#  (77.0, '2010-07-02'),
#  (77.0, '2010-07-03'),
#  (78.0, '2010-07-04'),
#  (78.0, '2010-07-05'),
#  (76.0, '2010-07-06'),
#  (74.0, '2010-07-07'),
#  (76.0, '2010-07-08'),
#  (74.0, '2010-07-09'),
#  (76.0, '2010-07-10'),
#  (78.0, '2010-07-11'),
#  (77.0, '2010-07-12'),
#  (80.0, '2010-07-13'),
#  (78.0, '2010-07-16'),
#  (76.0, '2010-07-17'),
#  (77.0, '2010-07-18'),
#  (77.0, '2010-07-19'),
#  (80.0, '2010-07-21'),
#  (78.0, '2010-07-22'),
#  (80.0, '2010-07-24'),
#  (79.0, '2010-07-25'),
#  (78.0, '2010-07-26'),
#  (79.0, '2010-07-27'),
#  (78.0, '2010-07-28'),
#  (79.0, '2010-07-29'),
#  (78.0, '2010-07-30'),
#  (77.0, '2010-07-31'),
#  (77.0, '2011-07-01'),
#  (78.0, '2011-07-02'),
#  (78.0, '2011-07-03'),
#  (78.0, '2011-07-04'),
#  (78.0, '2011-07-05'),
#  (76.0, '2011-07-06'),
#  (76.0, '2011-07-07'),
#  (77.0, '2011-07-08'),
#  (77.0, '2011-07-09'),
#  (77.0, '2011-07-10'),
#  (78.0, '2011-07-11'),
#  (77.0, '2011-07-12'),
#  (73.0, '2011-07-13'),
# ...

# %%
# 3. Create a DataFrame from the list of temperatures for the month of June. 
temp_df_july = pd.DataFrame(results_july, columns = ['tob', 'date'])
temp_df_july.head()
# Out:
#     tob        date
# 0  75.0  2010-07-01
# 1  77.0  2010-07-02
# 2  77.0  2010-07-03
# 3  78.0  2010-07-04
# 4  78.0  2010-07-05

# %%
# 4. Calculate and print out the summary statistics for the June temperature DataFrame.
temp_df_july.describe()
# Out:
#                tob
# count  1711.000000
# mean     76.082408
# std       3.356532
# min      61.000000
# 25%      74.000000
# 50%      76.000000
# 75%      78.000000
# max      87.000000

# %%
# 5. Return to your challenge instructions to compare your summary statistics

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
results_dec = session.query(Measurement.tobs, Measurement.date).filter(extract('month', Measurement.date) == 12)

# %%
# 7. Convert the December temperatures to a list.
results_dec.all()
# Out:
# [(76.0, '2010-12-01'),
#  (74.0, '2010-12-03'),
#  (74.0, '2010-12-04'),
#  (64.0, '2010-12-06'),
#  (64.0, '2010-12-07'),
#  (67.0, '2010-12-08'),
#  (77.0, '2010-12-09'),
#  (66.0, '2010-12-10'),
#  (69.0, '2010-12-11'),
#  (68.0, '2010-12-12'),
#  (68.0, '2010-12-13'),
#  (71.0, '2010-12-14'),
#  (74.0, '2010-12-15'),
#  (67.0, '2010-12-16'),
#  (66.0, '2010-12-17'),
#  (69.0, '2010-12-18'),
#  (71.0, '2010-12-19'),
#  (70.0, '2010-12-23'),
#  (70.0, '2010-12-24'),
#  (74.0, '2010-12-26'),
#  (74.0, '2010-12-27'),
#  (71.0, '2010-12-28'),
#  (75.0, '2010-12-29'),
#  (75.0, '2010-12-30'),
#  (72.0, '2010-12-31'),
#  (69.0, '2011-12-01'),
#  (68.0, '2011-12-02'),
#  (73.0, '2011-12-03'),
#  (74.0, '2011-12-04'),
#  (73.0, '2011-12-05'),
#  (73.0, '2011-12-06'),
#  (73.0, '2011-12-07'),
#  (73.0, '2011-12-08'),
#  (71.0, '2011-12-09'),
#  (73.0, '2011-12-10'),
#  (73.0, '2011-12-11'),
#  (77.0, '2011-12-12'),
#  (72.0, '2011-12-13'),
#  (71.0, '2011-12-14'),
#  (73.0, '2011-12-15'),
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
temp_df_dec = pd.DataFrame(results_dec, columns = ['tob', 'date'])
temp_df_dec.head()
# Out:
#     tob        date
# 0  76.0  2010-12-01
# 1  74.0  2010-12-03
# 2  74.0  2010-12-04
# 3  64.0  2010-12-06
# 4  64.0  2010-12-07

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
temp_df_dec.describe()
# Out:
#                tob
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %%
# 10. Return to your challenge instructions to compare your summary statistics
